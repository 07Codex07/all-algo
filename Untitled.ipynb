# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
df = pd.read_csv('heart.csv')

# %%
df.head(2)
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# 1              Yes  Very good        7.0     No            No         No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
df = df.iloc[: , [0,1,2,3,4,5,6,8,9,11,12,13,14,15,16,17]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   Sex               319795 non-null  object
#  8   AgeCategory       319795 non-null  object
#  9   Diabetic          319795 non-null  object
#  10  PhysicalActivity  319795 non-null  object
#  11  GenHealth         319795 non-null  object
#  12  SleepTime         319795 non-null  float64
#  13  Asthma            319795 non-null  object
#  14  KidneyDisease     319795 non-null  object
# ...

# %%
## Mapping

# %%
df.head(1)
# Out:
#   HeartDisease   BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.6     Yes              No     No             3.0
#
#    MentalHealth     Sex AgeCategory Diabetic PhysicalActivity  GenHealth  \
# 0          30.0  Female       55-59      Yes              Yes  Very good
#
#    SleepTime Asthma KidneyDisease SkinCancer
# 0        5.0    Yes            No        Yes

# %%
columns = ['HeartDisease', 'Smoking', 'AlcoholDrinking', 'Stroke', 'Diabetic', 'PhysicalActivity', 'Asthma', 'KidneyDisease', 'SkinCancer']
df[columns] = df[columns].apply(lambda x: x.map({'Yes': 1, 'No': 0}))
# Out:
# C:\Users\vinay\AppData\Local\Temp\ipykernel_77112\3485200124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columns] = df[columns].apply(lambda x: x.map({'Yes': 1, 'No': 0}))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  int64
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  int64
#  3   AlcoholDrinking   319795 non-null  int64
#  4   Stroke            319795 non-null  int64
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   Sex               319795 non-null  object
#  8   AgeCategory       319795 non-null  object
#  9   Diabetic          310455 non-null  float64
#  10  PhysicalActivity  319795 non-null  int64
#  11  GenHealth         319795 non-null  object
#  12  SleepTime         319795 non-null  float64
#  13  Asthma            319795 non-null  int64
#  14  KidneyDisease     319795 non-null  int64
#  15  SkinCancer        319795 non-null  int64
# ...

# %%
sns.countplot(data=df, x='HeartDisease')
plt.title('Heart Disease Distribution')
plt.show()

# %%
pd.crosstab(df['HeartDisease'], df['Smoking']).plot(kind='bar', stacked=True)
plt.title('Heart Disease vs Smoking')
plt.xlabel('Heart Disease')
plt.ylabel('Count')
plt.show()

# %%
sns.histplot(df['BMI'], kde=True)
plt.title('BMI Distribution')
plt.show()
# Out:
# C:\Users\vinay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(df[['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']])
plt.title('Pairplot of Numerical Columns')
plt.show()
# Out:
# C:\Users\vinay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\vinay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\vinay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
correlation_matrix = df[['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap for Numerical Columns')
plt.show()

# %%
df['HeartDisease'].value_counts()
# Out:
# HeartDisease
# 0    292422
# 1     27373
# Name: count, dtype: int64

# %%
cross = pd.crosstab(df['Smoking'], df['HeartDisease'], normalize='index')
cross.plot(kind='bar', stacked=True)
plt.title('Smoking vs Heart Disease')
plt.ylabel('Proportion')
plt.show()

# %%
sns.boxplot(x='HeartDisease', y='BMI', data=df)
plt.title('BMI Distribution by Heart Disease')
plt.show()

sns.boxplot(x='HeartDisease', y='SleepTime', data=df)
plt.title('Sleep Time by Heart Disease')
plt.show()

# %%
import seaborn as sns

corr_matrix = df[['HeartDisease', 'BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation with Heart Disease')
plt.show()

# %%
g = sns.FacetGrid(df, col="Sex", row="HeartDisease", margin_titles=True)
g.map_dataframe(sns.histplot, x="BMI")
plt.show()
# Out:
# C:\Users\vinay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\vinay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\vinay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df.groupby('AgeCategory')['HeartDisease'].mean().sort_values(ascending=False).plot(kind='bar', color='salmon')
plt.title('Heart Disease Rate by Age Category')
plt.ylabel('Proportion of Heart Disease')
plt.xlabel('Age Category')
plt.xticks(rotation=45)
plt.show()

# %%
heat_df = df.pivot_table(index='Sex', columns='Smoking', values='HeartDisease', aggfunc='mean')
sns.heatmap(heat_df, annot=True, cmap='Reds', fmt='.2f')
plt.title('Heart Disease Rate: Sex vs Smoking')
plt.show()

# %%
# Convert AgeCategory to ordered
age_order = ['18-24', '25-29', '30-34', '35-39', '40-44', '45-49', 
             '50-54', '55-59', '60-64', '65-69', '70-74', '75-79', '80 or older']

df['AgeCategory'] = pd.Categorical(df['AgeCategory'], categories=age_order, ordered=True)
age_heart = df.groupby('AgeCategory')['HeartDisease'].mean()

age_heart.plot(kind='line', marker='o', color='green')
plt.title('Heart Disease Rate by Age Group')
plt.ylabel('Heart Disease Rate')
plt.xlabel('Age Category')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\vinay\AppData\Local\Temp\ipykernel_77112\1209346989.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['AgeCategory'] = pd.Categorical(df['AgeCategory'], categories=age_order, ordered=True)
# C:\Users\vinay\AppData\Local\Temp\ipykernel_77112\1209346989.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_heart = df.groupby('AgeCategory')['HeartDisease'].mean()

# %%
df['HeartDisease'].value_counts()
# Out:
# HeartDisease
# 0    292422
# 1     27373
# Name: count, dtype: int64

# %%
sns.pairplot(df.sample(1000), hue='HeartDisease')
plt.show()
# Out:
# C:\Users\vinay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\vinay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\vinay\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
#1st problem that cann be seen in here is imbalanced data, i.e. here the ratio of patients with heart disease to those of not is 1:10 approx. 
#which is a huge imbalance . in this condition the end result i.e. the accuracy of the model would be arround 90 percent or even above but 
#in reality the acurracy of minority section would be worse, to correct this , here are the following steps.

#1 Undersampling
#2 Oversampling
#3 SMOTE (sample - factor[sample - neighbor])
#4 Ensemble Learning

# I think for my model SMOTE would go great.

# %%
categorical_cols = df[['Sex', 'AgeCategory', 'GenHealth']]  # adjust if needed

preprocessor = ColumnTransformer([
    ('cat', OneHotEncoder(drop='first'), categorical_cols)
], remainder='passthrough')  # keep the rest (numerical)

# %%
df.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0             3.0
# 1             0  20.34        0                0       1             0.0
# 2             0  26.58        1                0       0            20.0
# 3             0  24.21        0                0       0             0.0
# 4             0  23.71        0                0       0            28.0
#
#    MentalHealth     Sex  AgeCategory  Diabetic  PhysicalActivity  GenHealth  \
# 0          30.0  Female        55-59       1.0                 1  Very good
# 1           0.0  Female  80 or older       0.0                 1  Very good
# 2          30.0    Male        65-69       1.0                 1       Fair
# 3           0.0  Female        75-79       0.0                 0       Good
# 4           0.0  Female        40-44       0.0                 1  Very good
#
#    SleepTime  Asthma  KidneyDisease  SkinCancer
# ...

# %%
X = df.drop('HeartDisease', axis=1)
y = df['HeartDisease']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
categorical_cols = ['Sex', 'AgeCategory', 'GenHealth']

preprocessor = ColumnTransformer([
    ('encoder', OneHotEncoder(drop='first'), categorical_cols)
], remainder='passthrough')

# Apply preprocessing
X_train_encoded = preprocessor.fit_transform(X_train)
X_test_encoded = preprocessor.transform(X_test)

# %%
smote = SMOTE(random_state=42)
X_train_balanced, y_train_balanced = smote.fit_resample(X_train_encoded, y_train)

# %%
df.isnull()
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0              False  False    False            False   False           False
# 1              False  False    False            False   False           False
# 2              False  False    False            False   False           False
# 3              False  False    False            False   False           False
# 4              False  False    False            False   False           False
# ...              ...    ...      ...              ...     ...             ...
# 319790         False  False    False            False   False           False
# 319791         False  False    False            False   False           False
# 319792         False  False    False            False   False           False
# 319793         False  False    False            False   False           False
# 319794         False  False    False            False   False           False
#
# ...

# %%
df['Diabetic'].isnull().sum()
# Out:
# 9340

# %%
nan_diabetic_rows = df[df['Diabetic'].isna()]

# %%
nan_diabetic_rows['HeartDisease'].value_counts()
# Out:
# HeartDisease
# 0    8443
# 1     897
# Name: count, dtype: int64

# %%
df = df.dropna(subset=['Diabetic'])

# %%
df['Diabetic'].isnull().sum()
# Out:
# 0

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train_balanced, y_train_balanced)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test_encoded)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[42207 14589]
#  [ 1188  4107]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.74      0.84     56796
#            1       0.22      0.78      0.34      5295
#
#     accuracy                           0.75     62091
#    macro avg       0.60      0.76      0.59     62091
# weighted avg       0.91      0.75      0.80     62091

# %%
X.shape
# Out:
# (310455, 15)

# %%
model = LogisticRegression(max_iter=1000, class_weight='balanced')

# %%
from imblearn.combine import SMOTETomek

smt = SMOTETomek(random_state=42)
X_train_smt, y_train_smt = smt.fit_resample(X_train_encoded, y_train)

# %%
from sklearn.metrics import roc_auc_score

y_proba = model.predict_proba(X_test_encoded)[:,1]
roc_auc_score(y_test, y_proba)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[81], line 3
#       1 from sklearn.metrics import roc_auc_score
# ----> 3 y_proba = model.predict_proba(X_test_encoded)[:,1]
#       4 roc_auc_score(y_test, y_proba)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1362, in LogisticRegression.predict_proba(self, X)
#    1336 def predict_proba(self, X):
#    1337     """
#    1338     Probability estimates.
#    1339
#    (...)
#    1360         where classes are ordered as they are in ``self.classes_``.
#    1361     """
# -> 1362     check_is_fitted(self)
#    1364     ovr = self.multi_class in ["ovr", "warn"] or (
#    1365         self.multi_class == "auto"
#    1366         and (
#    (...)
#    1369         )
#    1370     )
#    1371     if ovr:
#
# ...

# %%
from sklearn.linear_model import LogisticRegression

# Add class_weight='balanced' if needed
model = LogisticRegression(max_iter=1000)

# Fit the model on training data
model.fit(X_train_encoded, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
model.fit(X_train_balanced, y_train_balanced)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import roc_auc_score

y_proba = model.predict_proba(X_test_encoded)[:,1]
roc_auc_score(y_test, y_proba)
# Out:
# 0.8392334981363314

# %%
custom_threshold = 0.3
y_pred_custom = (y_proba >= custom_threshold).astype(int)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test, y_pred_custom))
print(classification_report(y_test, y_pred_custom))
# Out:
# [[32020 24776]
#  [  424  4871]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.56      0.72     56796
#            1       0.16      0.92      0.28      5295
#
#     accuracy                           0.59     62091
#    macro avg       0.58      0.74      0.50     62091
# weighted avg       0.92      0.59      0.68     62091

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Before SMOTE
print("Before SMOTE:", pd.Series(y_train).value_counts())

# After SMOTE
print("After SMOTE:", pd.Series(y_train_smt).value_counts())

# Optional: visualize
sns.countplot(x=y_train_smt)
plt.title("Class Distribution After SMOTETomek")
plt.show()
# Out:
# Before SMOTE: HeartDisease
# 0    227183
# 1     21181
# Name: count, dtype: int64
# After SMOTE: HeartDisease
# 0    225321
# 1    225321
# Name: count, dtype: int64

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(y_test, y_proba)

# Optional: plot it to find balance point
import matplotlib.pyplot as plt

plt.plot(thresholds, precision[:-1], label='Precision')
plt.plot(thresholds, recall[:-1], label='Recall')
plt.xlabel('Threshold')
plt.legend()
plt.grid()
plt.show()
